# %% [markdown]
# # Matplotlib Task

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use("seaborn")

# %%
data = pd.read_csv("pandas_tasks.csv")
data
# Out:
#         ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  \
# 0     5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4
# 1     1258  40   1   1   3   5   1   1     1     0  ...    4    1    4
# 2      331  18   2   4   6   3   2   1     0     0  ...   -1    1    1
# 3     6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4
# 4     8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4
# ...    ...  ..  ..  ..  ..  ..  ..  ..   ...   ...  ...  ...  ...  ...
# 7089  8378  57   2   3   3   1   2   2     0     1  ...   -1    1    4
# 7090   881  32   1   1   6   3   1   1     0     1  ...   -1    1    1
# 7091  6672  22   2   3   3   3   2   2     0     1  ...   -1    4    4
# 7092  5416  28   2   1   3   1   2   2     0     1  ...   -1    1    4
# 7093  3946  78   1   3   1   1   2   2     0     0  ...   -1    4    4
#
#       Latitude  Longitude  mobile_money  savings  borrowing  insurance  \
# ...

# %% [markdown]
# ## Instruction

# %% [markdown]
# * Using the loaded dataset, make a boxplot, barplot, histogram, and a scatter plot.
# * Ensure to provide appropriate labels, and titles where necessary.
# * In each plot, ensure to use all parameters used in the Matplolib tutorial.
# * Optionally, add additional parameters for each plot for some extra points.
# * For each of the plot, choose appropriate columns in the dataset. The explanation for each of the variables has been provided in a word document called `Variable_Codebook.docx`.

# %% [markdown]
# #### Boxplot

# %%
land_ownership = data['Q5'].tolist()
plt.boxplot(land_ownership)
plt.title("A Boxplot showing land ownership status of the population")
plt.ylabel("Land Ownership Status")
plt.show();

# %% [markdown]
# #### Barplot

# %%
age = data['Q1'].tolist()
literacy_in_english = data['Q19'].tolist()
plt.bar(literacy_in_english, age)
plt.title("A Bar plot of age and level of literacy in English")
plt.xlabel("Level of Literacy in English")
plt.ylabel("Age")
plt.show;

# %% [markdown]
# #### Histogram

# %%
education_level = data['Q4'].tolist()
plt.hist(education_level, bins = 7)
plt.title("A Histogram showing the distribution of highest level of education in a population")
plt.xlabel("Highest Level of Education")
plt.ylabel("Frequency")
plt.show;

# %% [markdown]
# #### Scatter Plot

# %%
longitude = data['Longitude'].tolist()
latitude = data['Latitude'].tolist()
plt.scatter(longitude, latitude)
plt.title("A scatter plot showing the relationship between the longitude and the latitude of the population")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
